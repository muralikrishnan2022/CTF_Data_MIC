# %% [markdown]
# <a href="https://colab.research.google.com/github/muralikrishnan2022/CTF_Data_MIC/blob/main/MIC_CTF2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# Assuming you have a DataFrame named 'df'
df= pd.read_csv('/content/FIFA 19 data.csv')

# Example using a DataFrame
num_rows, num_columns = df.shape

print(f"Number of Rows: {num_rows}")
print(f"Number of Columns: {num_columns}")
# Out:
# Number of Rows: 17219
# Number of Columns: 82

# %%
df
# Out:
#                     Name  Age          Nationality  Overall  Potential  \
# 0               L. Messi   31            Argentina       94         94
# 1      Cristiano Ronaldo   33             Portugal       94         94
# 2              Neymar Jr   26               Brazil       92         93
# 3                 De Gea   27                Spain       91         93
# 4           K. De Bruyne   27              Belgium       91         92
# ...                  ...  ...                  ...      ...        ...
# 17214         S. Griffin   18  Republic of Ireland       47         67
# 17215        K. Fujikawa   19                Japan       47         61
# 17216           J. Young   18             Scotland       47         62
# 17217       J. Lundstram   19              England       47         65
# 17218          B. Worman   16              England       47         67
#
#                       Club        Value      Wage  Special  \
# ...

# %%
rated_80_players = df[df['Overall'] == 80]
total_rated_80_players = len(rated_80_players)
print(f'Total number of 80-rated players in FIFA 19: {total_rated_80_players}')
# Out:
# Total number of 80-rated players in FIFA 19: 143

# %%
# Filter Spanish players (assuming 'Nationality' is the column with nationality information)
spanish_players = df[df['Nationality'] == 'Spain']

# Get the total number of Spanish players
total_spanish_players = len(spanish_players)

# Print the result
print(f'Total number of Spanish players in FIFA 19: {total_spanish_players}')
# Out:
# Total number of Spanish players in FIFA 19: 1015

# %%
filtered_players = df[(df['Value'] >= 10000) & (df['Value'] <= 20000)]

# Check if there are players in the specified range
if not filtered_players.empty:
    # Calculate the mean value of players within the range
    mean_value = round(filtered_players['Value'].mean(), 2)
    print(f'Average value of players between 10,000 and 20,000 coins: {mean_value}')
else:
    print('No players found in the specified value range.')
# Out:
# Average value of players between 10,000 and 20,000 coins: 15714.29

# %%
# Filter players within the specified value range (1000 to 2000)
filtered_players = df[(df['Value'] >= 10000) & (df['Value'] <= 20000)]

filtered_players
# Out:
#                    Name  Age          Nationality  Overall  Potential  \
# 12396           P. Gori   38                Italy       63         63
# 12639        S. Bywater   37              England       63         63
# 12657        M. McNulty   37  Republic of Ireland       63         63
# 12658          L. Corti   37            Argentina       63         63
# 13502    F. Al Shammari   37         Saudi Arabia       61         61
# 13779      Y. Gutiérrez   37               Mexico       61         61
# 14200          Yang Jun   37             China PR       60         60
# 14545         M. Gurski   39              Germany       60         60
# 14812          M. Tyler   41              England       59         59
# 14884        S. Shearer   37             Scotland       59         59
# 14961       S. Bengriba   37               France       59         59
# 15011           D. Nasu   36                Japan       59         59
# ...

# %%
average_overall_score = filtered_players['Overall'].mean()

print(f"\nAverage Overall Score: {average_overall_score:.2f}")
# Out:
# Average Overall Score: 56.66

# %%
import pandas as pd

# Load the dataset
hp_df = pd.read_csv('/content/harry_potter.csv')

hp_df
# Out:
#         ID  Intelligence Blood Status  Loyalty Gender  \
# 0        1          30.0  Muggle Born     37.0      F
# 1        2          32.0   Pure Blood     42.0      F
# 2        3          32.0   Pure Blood     38.0      F
# 3        4          28.0  Muggle Born     36.0      F
# 4        5          28.0  Muggle Born     40.0      F
# ...    ...           ...          ...      ...    ...
# 1995  1996          29.0   Pure Blood     35.0      F
# 1996  1997          30.0   Pure Blood     40.0      M
# 1997  1998          33.0   Pure Blood     41.0      M
# 1998  1999          30.0  Muggle Born     40.0      M
# 1999  2000          30.0  Muggle Born     39.0      F
#
#      What are you curious about?  Affinity to Dark Arts  \
# 0             World after we die                  51.94
# 1             World after we die                  54.00
# 2             World after we die                  38.61
# 3              Magical Creatures                  47.50
# ...

# %% [markdown]
# this is for cigarette question

# %%
import pandas as pd

# Assuming you have a DataFrame named 'df'
df2= pd.read_csv('/content/acp-r1-r12-2016-2022-v1.6.csv', encoding='latin-1')
# Example using a DataFrame
num_rows, num_columns = df2.shape

print(f"Number of Rows: {num_rows}")
print(f"Number of Columns: {num_columns}")
# Out:
# Number of Rows: 215449
# Number of Columns: 28
# <ipython-input-20-f5069ecf005b>:4: DtypeWarning: Columns (0,1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df2= pd.read_csv('/content/acp-r1-r12-2016-2022-v1.6.csv', encoding='latin-1')

# %%
df2
# Out:
#        Store_ID Round Fieldworker_Code   Country Currency   Day  Month  \
# 0         123.0     1                F   Lesotho      LSL  18.0    1.0
# 1          51.0     1                B   Namibia      NAD  18.0    1.0
# 2          51.0     1                B   Namibia      NAD  18.0    1.0
# 3          52.0     1                B   Namibia      NAD  19.0    1.0
# 4          33.0     1                A    Uganda      UGX  22.0    1.0
# ...         ...   ...              ...       ...      ...   ...    ...
# 215444    416.0    12              251   Lesotho      LSL  20.0    7.0
# 215445    449.0    12              251   Lesotho      LSL  20.0    7.0
# 215446     17.0    12              309  Zimbabwe      ZAR  20.0    7.0
# 215447    608.0    12              277   Lesotho      LSL  19.0    7.0
# 215448    659.0    12              301  Zimbabwe     BOND  28.0    6.0
#
#           Year       Date        Province  ... Quantity Unusual_Quantity_Flg  \
# ...

# %%
namibia=df2[df2['Country']=="Namibia"]
namibia
# Out:
#        Store_ID Round Fieldworker_Code  Country Currency   Day  Month    Year  \
# 1          51.0     1                B  Namibia      NAD  18.0    1.0  2016.0
# 2          51.0     1                B  Namibia      NAD  18.0    1.0  2016.0
# 3          52.0     1                B  Namibia      NAD  19.0    1.0  2016.0
# 20         51.0     1                B  Namibia      NAD  18.0    1.0  2016.0
# 21         51.0     1                B  Namibia      NAD  18.0    1.0  2016.0
# ...         ...   ...              ...      ...      ...   ...    ...     ...
# 200140   1378.0    11              307  Namibia      NAD  22.0    1.0  2022.0
# 200158   1366.0    11              281  Namibia      NAD   6.0    1.0  2022.0
# 200167   1207.0    11              307  Namibia      NAD  30.0   12.0  2021.0
# 200172   1327.0    11              281  Namibia      NAD  23.0   12.0  2021.0
# 200181   1205.0    11              307  Namibia      NAD  30.0   12.0  2021.0
#
# ...

# %%
import pandas as pd

# Load your Hogwarts Houses dataset
# Replace 'hogwarts_dataset.csv' with the actual filename or path to your dataset
hogwarts_data = pd.read_csv('/content/harry_potter.csv')

# Assuming your dataset has columns like 'House' and 'Kindness'
# Calculate the mean kindness for each house
average_kindness_per_house = hogwarts_data.groupby('House')['Kindness'].mean()

# Find the house with the highest average kindness
house_with_highest_kindness = average_kindness_per_house.idxmax()
highest_kindness_value = average_kindness_per_house.max()

# Display the result
rounded_off_mean_kindness = round(highest_kindness_value, 2)
print(f"{house_with_highest_kindness}, {rounded_off_mean_kindness}")
# Out:
# Hufflepuff, 51.56

# %%
slytherin_data = hogwarts_data[hogwarts_data['House'] == 'Slytherin']

# Check if there is any data for Slytherin
if not slytherin_data.empty:
    # Calculate the mean affinity to Dark Arts for Slytherin
    average_affinity_slytherin = slytherin_data['Affinity to Dark Arts'].mean()

    # Display the result
    rounded_off_affinity_slytherin = round(average_affinity_slytherin, 2)
    print(f"The average affinity to Dark Arts for Slytherin house is: {rounded_off_affinity_slytherin}")
else:
    print("No data available for Slytherin house.")
# Out:
# No data available for Slytherin house.

# %%
import pandas as pd

# Replace 'your_dataset.csv' with the actual path or URL of your dataset
df = pd.read_csv('/content/acp-r1-r12-2016-2022-v1.6.csv', encoding="latin")

# Filter data for the suburb 'Windhoek West'
windhoek_west_data = df[df['Suburb'] == 'Windhoek West']

# Count the number of unique cigarette brands in Windhoek West
unique_brands_count = windhoek_west_data['Brand'].nunique()

print(f"Total number of unique cigarette brands in Windhoek West: {unique_brands_count}")
# Out:
# Total number of unique cigarette brands in Windhoek West: 22
# <ipython-input-73-d385ea18d30d>:4: DtypeWarning: Columns (0,1,2) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv('/content/acp-r1-r12-2016-2022-v1.6.csv', encoding="latin")
